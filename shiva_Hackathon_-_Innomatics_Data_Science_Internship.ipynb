# %%
import pandas as pd

# %%
movie = pd.read_csv(r"C:\Users\Shiva sai\Downloads\movie_data\movies.csv")

# %%
movie.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
# What is the shape of "movies.csv"?
movie.shape
# Out:
# (9742, 3)

# %%
rating = pd.read_csv(r"C:\Users\Shiva sai\Downloads\movie_data\ratings.csv")

# %%
rating.head()
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931

# %%
# What is the shape of "ratings.csv"?
rating.shape
# Out:
# (100836, 4)

# %%
# How many unique "userId" are available in "ratings.csv"?
rating['userId'].nunique()
# Out:
# 610

# %%
#Which movie has recieved maximum number of user ratings?
mr =movie.merge(rating,on = 'movieId').groupby(['rating','title'])[['rating']].count().rename(columns = {'rating':'count'}).sort_values(by ='count',ascending = False).reset_index()
mr
# Out:
#        rating                                      title  count
# 0         5.0           Shawshank Redemption, The (1994)    153
# 1         5.0                        Pulp Fiction (1994)    123
# 2         5.0                        Forrest Gump (1994)    116
# 3         5.0                         Matrix, The (1999)    109
# 4         5.0  Star Wars: Episode IV - A New Hope (1977)    104
# ...       ...                                        ...    ...
# 30408     2.0                    Who's That Girl? (1987)      1
# 30409     3.5                        Silent Movie (1976)      1
# 30410     3.5          Silent Night, Deadly Night (1984)      1
# 30411     3.5                      Silk Stockings (1957)      1
# 30412     0.5                (500) Days of Summer (2009)      1
#
# [30413 rows x 3 columns]

# %%
tag = pd.read_csv(r"C:\Users\Shiva sai\Downloads\movie_data\tags.csv")

# %%
tag.head()
# Out:
#    userId  movieId              tag   timestamp
# 0       2    60756            funny  1445714994
# 1       2    60756  Highly quotable  1445714996
# 2       2    60756     will ferrell  1445714992
# 3       2    89774     Boxing story  1445715207
# 4       2    89774              MMA  1445715200

# %%
mt =movie.merge(tag,on='movieId')
mt
# Out:
#       movieId                           title  \
# 0           1                Toy Story (1995)
# 1           1                Toy Story (1995)
# 2           1                Toy Story (1995)
# 3           2                  Jumanji (1995)
# 4           2                  Jumanji (1995)
# ...       ...                             ...
# 3678   187595  Solo: A Star Wars Story (2018)
# 3679   193565       Gintama: The Movie (2010)
# 3680   193565       Gintama: The Movie (2010)
# 3681   193565       Gintama: The Movie (2010)
# 3682   193565       Gintama: The Movie (2010)
#
#                                            genres  userId               tag  \
# 0     Adventure|Animation|Children|Comedy|Fantasy     336             pixar
# 1     Adventure|Animation|Children|Comedy|Fantasy     474             pixar
# 2     Adventure|Animation|Children|Comedy|Fantasy     567               fun
# 3                      Adventure|Children|Fantasy      62           fantasy
# ...

# %%
# Select all the correct tags submitted by users to "Matrix, The (1999)" movie?
mt[mt['title']=='Matrix, The (1999)']
# Out:
#       movieId               title                  genres  userId  \
# 1313     2571  Matrix, The (1999)  Action|Sci-Fi|Thriller     424
# 1314     2571  Matrix, The (1999)  Action|Sci-Fi|Thriller     424
# 1315     2571  Matrix, The (1999)  Action|Sci-Fi|Thriller     474
# 1316     2571  Matrix, The (1999)  Action|Sci-Fi|Thriller     537
# 1317     2571  Matrix, The (1999)  Action|Sci-Fi|Thriller     537
#
#                      tag   timestamp
# 1313        martial arts  1457842912
# 1314              sci-fi  1457842899
# 1315  alternate universe  1137204991
# 1316          philosophy  1424141098
# 1317    post apocalyptic  1424141101

# %%
mr =movie.merge(rating,on = 'movieId').groupby('title')[['rating']].mean().rename(columns = {'rating':'mean'}).\
sort_values(by ='mean',ascending = False).reset_index()
mr
# Out:
#                                         title  mean
# 0                   Gena the Crocodile (1969)   5.0
# 1                         True Stories (1986)   5.0
# 2               Cosmic Scrat-tastrophe (2015)   5.0
# 3                     Love and Pigeons (1985)   5.0
# 4         Red Sorghum (Hong gao liang) (1987)   5.0
# ...                                       ...   ...
# 9714                    Don't Look Now (1973)   0.5
# 9715  Journey 2: The Mysterious Island (2012)   0.5
# 9716       Joe Dirt 2: Beautiful Loser (2015)   0.5
# 9717       Jesus Christ Vampire Hunter (2001)   0.5
# 9718          Fullmetal Alchemist 2018 (2017)   0.5
#
# [9719 rows x 2 columns]

# %%
#What is the average user rating for movie named "Terminator 2: Judgment Day (1991)"?
mr[mr['title']=="Terminator 2: Judgment Day (1991)"]
# Out:
#                                   title      mean
# 2294  Terminator 2: Judgment Day (1991)  3.970982

# %%
mr =movie.merge(rating,on = 'movieId')
mr
# Out:
#         movieId                                      title  \
# 0             1                           Toy Story (1995)
# 1             1                           Toy Story (1995)
# 2             1                           Toy Story (1995)
# 3             1                           Toy Story (1995)
# 4             1                           Toy Story (1995)
# ...         ...                                        ...
# 100831   193581  Black Butler: Book of the Atlantic (2017)
# 100832   193583               No Game No Life: Zero (2017)
# 100833   193585                               Flint (2017)
# 100834   193587        Bungo Stray Dogs: Dead Apple (2018)
# 100835   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                              genres  userId  rating  \
# 0       Adventure|Animation|Children|Comedy|Fantasy       1     4.0
# 1       Adventure|Animation|Children|Comedy|Fantasy       5     4.0
# ...

# %%
#How does the data distribution of user ratings for "Fight Club (1999)" movie looks like?
mr[mr['title']=="Fight Club (1999)"]['rating'].plot(kind ='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
mr =movie.merge(rating,on = 'movieId').groupby(['movieId','title'])['rating'].agg(['mean','count']).reset_index().sort_values(by ='mean')
mr
# Out:
#       movieId                                  title  mean  count
# 5541    26696                       Lionheart (1990)   0.5      1
# 2685     3604                           Gypsy (1962)   0.5      1
# 4872     7312                Follow Me, Boys! (1966)   0.5      1
# 9099   145724                  Idaho Transfer (1973)   0.5      1
# 7280    76030                         Case 39 (2009)   0.5      1
# ...       ...                                    ...   ...    ...
# 2876     3851         I'm the One That I Want (2000)   5.0      1
# 8734   128087  Trinity and Sartana Are Coming (1972)   5.0      1
# 5862    33138                     Palindromes (2004)   5.0      1
# 7960    96608                  Runaway Brain (1995)    5.0      1
# 6482    53355         Sun Alley (Sonnenallee) (1999)   5.0      1
#
# [9724 rows x 4 columns]

# %%
# Which movie is the most popular based on  average user ratings?

# %%
mr[mr['title']=='Godfather, The (1972)']
# Out:
#      movieId                  title      mean  count
# 659      858  Godfather, The (1972)  4.289062    192

# %%
mr[mr['title']=='Shawshank Redemption, The (1994)']
# Out:
#      movieId                             title      mean  count
# 277      318  Shawshank Redemption, The (1994)  4.429022    317

# %%
mr[mr['title']=='Wolf of Wall Street, The (2013)']
# Out:
#       movieId                            title      mean  count
# 8287   106782  Wolf of Wall Street, The (2013)  3.916667     54

# %%
mr[mr['title']=='Jumanji (1995)']
# Out:
#    movieId           title      mean  count
# 1        2  Jumanji (1995)  3.431818    110

# %%
# Select all the correct options which comes under top 5 popular movies based on number of user ratings.
#"Mandatory Operation"
mr[mr['count']>50].sort_values(by ='count',ascending =False)
# Out:
#       movieId                             title      mean  count
# 314       356               Forrest Gump (1994)  4.164134    329
# 277       318  Shawshank Redemption, The (1994)  4.429022    317
# 257       296               Pulp Fiction (1994)  4.197068    307
# 510       593  Silence of the Lambs, The (1991)  4.161290    279
# 1938     2571                Matrix, The (1999)  4.192446    278
# ...       ...                               ...       ...    ...
# 3147     4239                       Blow (2001)  3.813725     51
# 118       145                   Bad Boys (1995)  3.245098     51
# 1562     2100                     Splash (1984)  3.117647     51
# 3539     4848           Mulholland Drive (2001)  3.843137     51
# 915      1215           Army of Darkness (1993)  4.039216     51
#
# [436 rows x 4 columns]

# %%
mrt=mr.merge(tag,on = 'movieId').sort_values(by ='count',ascending =False)
mrt
# Out:
#       movieId                      title      mean  count  userId  \
# 2993      356        Forrest Gump (1994)  4.164134    329     567
# 2992      356        Forrest Gump (1994)  4.164134    329     567
# 2994      356        Forrest Gump (1994)  4.164134    329     567
# 2986      356        Forrest Gump (1994)  4.164134    329     474
# 2987      356        Forrest Gump (1994)  4.164134    329     474
# ...       ...                        ...       ...    ...     ...
# 2392     7217        Dark Passage (1947)  4.000000      1     474
# 2391     7141  My Flesh and Blood (2003)  4.000000      1     474
# 2390     7714             Camelot (1967)  4.000000      1     474
# 2389     7713          Cat People (1942)  4.000000      1     474
# 3661     3951    Two Family House (2000)  5.000000      1     474
#
#                    tag   timestamp
# 2993      heartwarming  1525287541
# 2992         emotional  1525287537
# 2994          touching  1525287539
# ...

# %%
# Which Sci-Fi movie is "third most popular" based on the number of user ratings?
mrt[(mrt['tag']=='Sci-Fi')|(mrt['tag']=='sci-fi')]
# Out:
#       movieId                                              title      mean  \
# 3031     2571                                 Matrix, The (1999)  4.192446
# 3316      260          Star Wars: Episode IV - A New Hope (1977)  4.231076
# 3333      260          Star Wars: Episode IV - A New Hope (1977)  4.231076
# 3328      260          Star Wars: Episode IV - A New Hope (1977)  4.231076
# 2230      589                  Terminator 2: Judgment Day (1991)  3.970982
# 3283     1196  Star Wars: Episode V - The Empire Strikes Back...  4.215640
# 2699    79132                                   Inception (2010)  4.066434
# 2002     1240                             Terminator, The (1984)  3.896947
# 2211     1200                                      Aliens (1986)  3.964286
# 2785      541                                Blade Runner (1982)  4.100806
# 1982      924                       2001: A Space Odyssey (1968)  3.894495
# ...

# %%
links = pd.read_csv(r"C:\Users\Shiva sai\Downloads\movie_data\links.csv")
links.head()
# Out:
#    movieId  imdbId   tmdbId
# 0        1  114709    862.0
# 1        2  113497   8844.0
# 2        3  113228  15602.0
# 3        4  114885  31357.0
# 4        5  113041  11862.0

# %%
mr
# Out:
#       movieId                                  title  mean  count
# 5541    26696                       Lionheart (1990)   0.5      1
# 2685     3604                           Gypsy (1962)   0.5      1
# 4872     7312                Follow Me, Boys! (1966)   0.5      1
# 9099   145724                  Idaho Transfer (1973)   0.5      1
# 7280    76030                         Case 39 (2009)   0.5      1
# ...       ...                                    ...   ...    ...
# 2876     3851         I'm the One That I Want (2000)   5.0      1
# 8734   128087  Trinity and Sartana Are Coming (1972)   5.0      1
# 5862    33138                     Palindromes (2004)   5.0      1
# 7960    96608                  Runaway Brain (1995)    5.0      1
# 6482    53355         Sun Alley (Sonnenallee) (1999)   5.0      1
#
# [9724 rows x 4 columns]

# %%
mr50 = mr[mr['count']>50]
mr50
# Out:
#       movieId                                              title      mean  \
# 2028     2701                              Wild Wild West (1999)  2.207547
# 379       435                                   Coneheads (1993)  2.420635
# 376       432  City Slickers II: The Legend of Curly's Gold (...  2.645455
# 145       173                                 Judge Dredd (1995)  2.669355
# 144       172                             Johnny Mnemonic (1995)  2.679245
# ...       ...                                                ...       ...
# 602       750  Dr. Strangelove or: How I Learned to Stop Worr...  4.268041
# 974      1276                              Cool Hand Luke (1967)  4.271930
# 2224     2959                                  Fight Club (1999)  4.272936
# 659       858                              Godfather, The (1972)  4.289062
# 277       318                   Shawshank Redemption, The (1994)  4.429022
#
#       count
# 2028     53
# 379      63
# 376      55
# 145      62
# ...

# %%
mrl =links.merge(mr50,on='movieId')
mrl
# Out:
#      movieId   imdbId    tmdbId                             title      mean  \
# 0          1   114709     862.0                  Toy Story (1995)  3.920930
# 1          2   113497    8844.0                    Jumanji (1995)  3.431818
# 2          3   113228   15602.0           Grumpier Old Men (1995)  3.259615
# 3          6   113277     949.0                       Heat (1995)  3.946078
# 4          7   114319   11860.0                    Sabrina (1995)  3.185185
# ..       ...      ...       ...                               ...       ...
# 431   106782   993846  106646.0   Wolf of Wall Street, The (2013)  3.916667
# 432   109374  2278388  120467.0  Grand Budapest Hotel, The (2014)  3.778846
# 433   109487   816692  157336.0               Interstellar (2014)  3.993151
# 434   112852  2015381  118340.0    Guardians of the Galaxy (2014)  4.050847
# 435   122904  1431045  293660.0                   Deadpool (2016)  3.833333
#
#      count
# 0      215
# 1      110
# 2       52
# ...

# %%
# Mention the movieId of the movie which has the highest IMDB rating.
mrl.sort_values(by ='imdbId',ascending =False)
# Out:
#      movieId   imdbId    tmdbId                                   title  \
# 432   109374  2278388  120467.0        Grand Budapest Hotel, The (2014)
# 434   112852  2015381  118340.0          Guardians of the Galaxy (2014)
# 430    99114  1853728   68718.0                 Django Unchained (2012)
# 426    81845  1504320   45269.0               King's Speech, The (2010)
# 435   122904  1431045  293660.0                         Deadpool (2016)
# ..       ...      ...       ...                                     ...
# 123      923    33467      15.0                     Citizen Kane (1941)
# 102      596    32910   10895.0                        Pinocchio (1940)
# 171     1282    32455     756.0                         Fantasia (1940)
# 122      919    32138     630.0                Wizard of Oz, The (1939)
# 100      594    29583     408.0  Snow White and the Seven Dwarfs (1937)
#
#          mean  count
# 432  3.778846     52
# 434  4.050847     59
# 430  3.943662     71
# ...

# %%
mrlt =tag.merge(mrl,on = 'movieId')
mrlt
# Out:
#       userId  movieId                tag   timestamp   imdbId    tmdbId  \
# 0          2   106782              drugs  1445715054   993846  106646.0
# 1          2   106782  Leonardo DiCaprio  1445715051   993846  106646.0
# 2          2   106782    Martin Scorsese  1445715056   993846  106646.0
# 3        537   106782       Stock Market  1424142693   993846  106646.0
# 4        537   106782        Wall Street  1424142688   993846  106646.0
# ...      ...      ...                ...         ...      ...       ...
# 1325     567   112852      unlikely hero  1525285378  2015381  118340.0
# 1326     573    35836       BEST PICTURE  1186589105   405422    6957.0
# 1327     573    35836            classic  1186589105   405422    6957.0
# 1328     573    35836          hilarious  1186589105   405422    6957.0
# 1329     573    35836       steve carell  1186589105   405422    6957.0
#
#                                 title      mean  count
# ...

# %%
# Mention the movieId of the "Sci-Fi" movie which has the highest IMDB rating.
mrlt[(mrlt['tag']=='Sci-Fi')|(mrlt['tag']=='sci-fi')]
# Out:
#       userId  movieId     tag   timestamp   imdbId    tmdbId  \
# 19        49   109487  sci-fi  1493093332   816692  157336.0
# 22       424   109487  sci-fi  1457901808   816692  157336.0
# 107       76      260  sci-fi  1439165588    76759      11.0
# 119      205      260  sci-fi  1519899078    76759      11.0
# 124      424      260  sci-fi  1457900766    76759      11.0
# 584      424      541  sci-fi  1457900918    83658      78.0
# 600      424      589  sci-fi  1457844847   103064     280.0
# 639      424     1200  sci-fi  1457901245    90605     679.0
# 657      424     1240  Sci-Fi  1457901302    88247     218.0
# 688      424     2571  sci-fi  1457842899   133093     603.0
# 755      424     3527  sci-fi  1457901285    93773     106.0
# 763      477     3527  sci-fi  1269832609    93773     106.0
# 804      424    79132  sci-fi  1457844903  1375666   27205.0
# 969      599      924  sci-fi  1498456751    62622      62.0
# ...
